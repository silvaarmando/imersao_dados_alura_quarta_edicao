# %%
import pandas as pd

url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"

data = pd.read_csv(url)

# %%
data
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10006         Rua Manuel Onha, , 514        Vila Oratório  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas  \
# 0          1000        4          8      6
# 1           496        4          4      4
# ...

# %%
data.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
data.sample(10)
# Out:
#                                     Rua             Bairro     Cidade  \
# 3104                                NaN      Vila Madalena  São Paulo
# 8510           Rua Hilário Magro Junior            Butantã  São Paulo
# 543                   Rua Camundo, 119   Planalto Paulista  São Paulo
# 8425  Rua Doutor Flávio Américo Maurano    Fazenda Morumbi  São Paulo
# 9531              Rua São Roque, , 480        Vila Tolstoi  São Paulo
# 2938                                NaN    Jardim Paulista  São Paulo
# 1487                        Rua Araberi  Brooklin Paulista  São Paulo
# 5016   Rua Frederico Von Martius, , 73      Vila Monumento  São Paulo
# 8069                                NaN        Santo Amaro  São Paulo
# 6882                 Rua Estados Unidos     Jardim América  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas  \
# 3104       473        4          5      5
# 8510       500        5          6      4
# 543        365        7          1      3
# ...

# %%
data["Bairro"][5016]
# Out:
# 'Vila Monumento'

# %%
# Métodos diferentes de fazer a mesma coisa

# data.Metragem.mean()

data["Metragem"].mean()
# Out:
# 442.30065947242207

# %%
# data["Bairro"] == "Vila Mariana"

sum(data["Bairro"] == "Vila Mariana")
# Out:
# 184

# %%
have_price_vila_mariana = (data["Bairro"] == "Vila Mariana")

# %%
price_house_vila_mariana = data[have_price_vila_mariana]

price_house_vila_mariana
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
price_house_vila_mariana.sample(10)
# Out:
#                               Rua        Bairro     Cidade  Metragem  Quartos  \
# 2616  Rua José Vicente de Azevedo  Vila Mariana  São Paulo       240        3
# 6242       Praça Graciliano Ramos  Vila Mariana  São Paulo       236        4
# 4360             Rua Pero Correia  Vila Mariana  São Paulo       180        3
# 4395        Rua Colônia da Glória  Vila Mariana  São Paulo       185        3
# 6063                          NaN  Vila Mariana  São Paulo       195        4
# 4879                 Rua Gassipós  Vila Mariana  São Paulo       165        3
# 5314     Rua Carlos Vítor Cocozza  Vila Mariana  São Paulo       230        3
# 3634        Rua Morgado de Mateus  Vila Mariana  São Paulo       263        4
# 3362         Rua Machado de Assis  Vila Mariana  São Paulo       290        3
# 6154              Rua Sousa Ramos  Vila Mariana  São Paulo       250        3
#
#       Banheiros  Vagas                                 Valor
# ...

# %%
price_house_vila_mariana.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Metragem     233.619565
# Quartos        3.375000
# Banheiros      3.228261
# Vagas          2.929348
# dtype: float64

# %%
price_house_vila_mariana["Metragem"].mean()
# Out:
# 233.6195652173913

# %%
data["Bairro"].value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
data["Bairro"].value_counts().sample(10)
# Out:
# Jardim Itapemirim                   1
# Brooklin Paulista                 247
# Vila Talarico                       6
# Parque Santa Cecília                1
# Vila Santos                         8
# Parque Savoy City                   6
# Terceira Divisão de Interlagos      5
# Vila Paulo Silas                    3
# Parque das Paineiras                1
# Jardim Santo Amaro                 12
# Name: Bairro, dtype: int64

# %%
n_district_prices = data["Bairro"].value_counts()

# %%
n_district_prices.head(10).plot.bar()

# %%
n_district_prices.head(10).plot.hist()
